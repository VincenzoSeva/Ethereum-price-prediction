# %%
import pandas as pd
import numpy as np
import math
import datetime as dt
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM

plt.style.use('seaborn-darkgrid')

# %%
 #Data comes from:
# https://finance.yahoo.com/quote/ETH-USD/history?period1=1438905600&period2=1660694400&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true

root_path='/content/ETH-USD PRED.csv'

ETH_df = pd.read_csv(root_path)
ETH_df.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 1738  2022-08-13  1957.333984  2013.755737  1948.595215  1981.336548
# 1739  2022-08-14  1981.782471  2022.791504  1919.010132  1936.802002
# 1740  2022-08-15  1936.760498  2007.210327  1881.856812  1904.228149
# 1741  2022-08-16  1902.833130  1910.745361  1862.273438  1878.139404
# 1742  2022-08-17  1876.656494  1951.675659  1823.532227  1838.366943
#
#         Adj Close       Volume
# 1738  1981.336548  16038975216
# 1739  1936.802002  14062754456
# 1740  1904.228149  20349931313
# 1741  1878.139404  15637578930
# 1742  1838.366943  19144841216

# %%
ETH_df.shape
# Out:
# (1743, 7)

# %%
ETH_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1743 entries, 0 to 1742
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1743 non-null   object
#  1   Open       1743 non-null   float64
#  2   High       1743 non-null   float64
#  3   Low        1743 non-null   float64
#  4   Close      1743 non-null   float64
#  5   Adj Close  1743 non-null   float64
#  6   Volume     1743 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 95.4+ KB

# %%
#Converting 'Date' column from object dtype to datetime dtype
ETH_df_date = ETH_df.astype({'Date': 'datetime64'})
ETH_df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1743 entries, 0 to 1742
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1743 non-null   datetime64[ns]
#  1   Open       1743 non-null   float64
#  2   High       1743 non-null   float64
#  3   Low        1743 non-null   float64
#  4   Close      1743 non-null   float64
#  5   Adj Close  1743 non-null   float64
#  6   Volume     1743 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 95.4 KB

# %%
print('Null Values:',ETH_df_date.isnull().values.sum())
# Out:
# Null Values: 0

# %%
ETH_df_date.tail()
# Out:
#            Date         Open         High          Low        Close  \
# 1738 2022-08-13  1957.333984  2013.755737  1948.595215  1981.336548
# 1739 2022-08-14  1981.782471  2022.791504  1919.010132  1936.802002
# 1740 2022-08-15  1936.760498  2007.210327  1881.856812  1904.228149
# 1741 2022-08-16  1902.833130  1910.745361  1862.273438  1878.139404
# 1742 2022-08-17  1876.656494  1951.675659  1823.532227  1838.366943
#
#         Adj Close       Volume
# 1738  1981.336548  16038975216
# 1739  1936.802002  14062754456
# 1740  1904.228149  20349931313
# 1741  1878.139404  15637578930
# 1742  1838.366943  19144841216

# %%
ETH_df_date.set_index("Date").Close.plot(figsize=(24,7), title="Ethereum Price Trend")

# %%
ETH_Date=ETH_df_date.groupby('Date')
Price_by_date=ETH_Date['Close'].mean()
Price_by_date
# Out:
# Date
# 2017-11-09     320.884003
# 2017-11-10     299.252991
# 2017-11-11     314.681000
# 2017-11-12     307.907990
# 2017-11-13     316.716003
#                  ...
# 2022-08-13    1981.336548
# 2022-08-14    1936.802002
# 2022-08-15    1904.228149
# 2022-08-16    1878.139404
# 2022-08-17    1838.366943
# Name: Close, Length: 1743, dtype: float64

# %%
len(Price_by_date)
# Out:
# 1743

# %%
prediction_days = 60 #to divide train and test 

# Creating training dataset
df_train= Price_by_date[:len(Price_by_date)-prediction_days].values.reshape(-1,1)


# Test the last prediction_days 
df_test= Price_by_date[len(Price_by_date)-prediction_days:].values.reshape(-1,1)

# %%
df_test.shape,df_train.shape
# Out:
# ((60, 1), (1683, 1))

# %%
chosen_col = 'Close'

fig, ax = plt.subplots(1, figsize=(13, 7))
ax.plot(df_train, label='Train', linewidth=2)
ax.plot(df_test, label='Test', linewidth=2)
ax.set_ylabel('Price USD', fontsize=14)
ax.set_title('', fontsize=16)
ax.legend(loc='best', fontsize=16)

# %%
#scaling the data
scaler_train = MinMaxScaler(feature_range=(0, 1))
scaled_train = scaler_train.fit_transform(df_train)

scaler_test = MinMaxScaler(feature_range=(0, 1))
scaled_test = scaler_test.fit_transform(df_test)

# %%
#splitting the input sequence into windows of data

def dataset_period(dataset, back=5):
     
    dataX, dataY = [], []
    
    for i in range(len(dataset) - back):
        window = dataset[i:(i + back), 0]#getting windows of 5 timestamp each
        dataX.append(window)
        dataY.append(dataset[i + back, 0]) #getting the labels for each window
    return np.array(dataX), np.array(dataY)

X_train, y_train = dataset_period(scaled_train)

X_test, y_test= dataset_period(scaled_test)

print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test", y_test.shape)
# Out:
# X_train:  (1678, 5)
# y_train:  (1678,)
# X_test:  (55, 5)
# y_test (55,)

# %%
#need to reshape input to be a 3D Tensor
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1 ))

print("Shape of X_train: ", X_train.shape)
print("Shape of X_test: ", X_test.shape)
# Out:
# Shape of X_train:  (1678, 5, 1)
# Shape of X_test:  (55, 5, 1)

# %%
#using an LMST model
model = Sequential()

model.add(LSTM(units = 128, activation = 'tanh',return_sequences=True, input_shape = (X_train.shape[1], X_train.shape[2])))#set return_sequences=True 
model.add(Dropout(0.2))#regularisation

# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 64, return_sequences = True, input_shape = (X_train.shape[1], X_train.shape[2])))#set return_sequences=True 
model.add(Dropout(0.2))



#Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 64, return_sequences = True, input_shape = (X_train.shape[1], X_train.shape[2])))#set return_sequences=True 
model.add(Dropout(0.2))


# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 64, input_shape = (X_train.shape[1], X_train.shape[2]))) 
model.add(Dropout(0.2))


# Adding the output layer
model.add(Dense(units = 1))

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, 5, 128)            66560
#
#  dropout_14 (Dropout)        (None, 5, 128)            0
#
#  lstm_15 (LSTM)              (None, 5, 64)             49408
#
#  dropout_15 (Dropout)        (None, 5, 64)             0
#
#  lstm_16 (LSTM)              (None, 5, 64)             33024
#
#  dropout_16 (Dropout)        (None, 5, 64)             0
#
#  lstm_17 (LSTM)              (None, 64)                33024
#
#  dropout_17 (Dropout)        (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 182,081
# Trainable params: 182,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Compiling the model
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

checkpoint_path = 'best_model.hdf5'#for saving best model

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')


earlystopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

callbacks = [checkpoint, earlystopping]
#testing the model
history = model.fit(X_train, y_train, batch_size = 32, epochs = 300, verbose=1, shuffle=False, validation_data=(X_test, y_test), callbacks=callbacks)
# Out:
# Epoch 1/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0590
# Epoch 1: val_loss improved from inf to 0.08948, saving model to best_model.hdf5
# 53/53 [==============================] - 7s 35ms/step - loss: 0.0610 - val_loss: 0.0895
# Epoch 2/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0929
# Epoch 2: val_loss did not improve from 0.08948
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0922 - val_loss: 0.1158
# Epoch 3/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0254
# Epoch 3: val_loss improved from 0.08948 to 0.02985, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0252 - val_loss: 0.0298
# Epoch 4/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0200
# Epoch 4: val_loss improved from 0.02985 to 0.02814, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0218 - val_loss: 0.0281
# Epoch 5/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0052
# Epoch 5: val_loss improved from 0.02814 to 0.01996, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0056 - val_loss: 0.0200
# Epoch 6/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0057
# Epoch 6: val_loss improved from 0.01996 to 0.01809, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0063 - val_loss: 0.0181
# Epoch 7/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0085
# Epoch 7: val_loss improved from 0.01809 to 0.01795, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0088 - val_loss: 0.0180
# Epoch 8/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0092
# Epoch 8: val_loss did not improve from 0.01795
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0100 - val_loss: 0.0197
# Epoch 9/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0054
# Epoch 9: val_loss improved from 0.01795 to 0.01770, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0060 - val_loss: 0.0177
# Epoch 10/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0049
# Epoch 10: val_loss improved from 0.01770 to 0.01731, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0064 - val_loss: 0.0173
# Epoch 11/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 11: val_loss improved from 0.01731 to 0.01716, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0067 - val_loss: 0.0172
# Epoch 12/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0054
# Epoch 12: val_loss improved from 0.01716 to 0.01704, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0063 - val_loss: 0.0170
# Epoch 13/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0052
# Epoch 13: val_loss improved from 0.01704 to 0.01691, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0059 - val_loss: 0.0169
# Epoch 14/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 14: val_loss did not improve from 0.01691
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0057 - val_loss: 0.0170
# Epoch 15/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 15: val_loss improved from 0.01691 to 0.01680, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0066 - val_loss: 0.0168
# Epoch 16/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0056
# Epoch 16: val_loss improved from 0.01680 to 0.01668, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0060 - val_loss: 0.0167
# Epoch 17/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0046
# Epoch 17: val_loss improved from 0.01668 to 0.01664, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0054 - val_loss: 0.0166
# Epoch 18/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0047
# Epoch 18: val_loss improved from 0.01664 to 0.01658, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0052 - val_loss: 0.0166
# Epoch 19/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 19: val_loss improved from 0.01658 to 0.01655, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0050 - val_loss: 0.0166
# Epoch 20/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0043
# Epoch 20: val_loss did not improve from 0.01655
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0049 - val_loss: 0.0169
# Epoch 21/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0046
# Epoch 21: val_loss did not improve from 0.01655
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0052 - val_loss: 0.0166
# Epoch 22/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0044
# Epoch 22: val_loss improved from 0.01655 to 0.01645, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0050 - val_loss: 0.0165
# Epoch 23/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0039
# Epoch 23: val_loss did not improve from 0.01645
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0047 - val_loss: 0.0166
# Epoch 24/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0056
# Epoch 24: val_loss improved from 0.01645 to 0.01625, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0058 - val_loss: 0.0163
# Epoch 25/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0050
# Epoch 25: val_loss did not improve from 0.01625
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0053 - val_loss: 0.0164
# Epoch 26/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 26: val_loss improved from 0.01625 to 0.01615, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0054 - val_loss: 0.0162
# Epoch 27/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0047
# Epoch 27: val_loss improved from 0.01615 to 0.01605, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0051 - val_loss: 0.0160
# Epoch 28/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0044
# Epoch 28: val_loss improved from 0.01605 to 0.01589, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0159
# Epoch 29/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0039
# Epoch 29: val_loss did not improve from 0.01589
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0044 - val_loss: 0.0160
# Epoch 30/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0043
# Epoch 30: val_loss did not improve from 0.01589
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0046 - val_loss: 0.0160
# Epoch 31/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0040
# Epoch 31: val_loss improved from 0.01589 to 0.01572, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0045 - val_loss: 0.0157
# Epoch 32/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0039
# Epoch 32: val_loss did not improve from 0.01572
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0045 - val_loss: 0.0161
# Epoch 33/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0047
# Epoch 33: val_loss improved from 0.01572 to 0.01570, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0052 - val_loss: 0.0157
# Epoch 34/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0048
# Epoch 34: val_loss did not improve from 0.01570
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0051 - val_loss: 0.0157
# Epoch 35/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0044
# Epoch 35: val_loss improved from 0.01570 to 0.01556, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0052 - val_loss: 0.0156
# Epoch 36/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 36: val_loss improved from 0.01556 to 0.01530, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0048 - val_loss: 0.0153
# Epoch 37/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0038
# Epoch 37: val_loss did not improve from 0.01530
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0045 - val_loss: 0.0154
# Epoch 38/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0042
# Epoch 38: val_loss did not improve from 0.01530
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0155
# Epoch 39/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0043
# Epoch 39: val_loss improved from 0.01530 to 0.01509, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0052 - val_loss: 0.0151
# Epoch 40/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 40: val_loss did not improve from 0.01509
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0048 - val_loss: 0.0151
# Epoch 41/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0041
# Epoch 41: val_loss improved from 0.01509 to 0.01502, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0046 - val_loss: 0.0150
# Epoch 42/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0038
# Epoch 42: val_loss improved from 0.01502 to 0.01493, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0043 - val_loss: 0.0149
# Epoch 43/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 43: val_loss did not improve from 0.01493
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0039 - val_loss: 0.0151
# Epoch 44/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0043
# Epoch 44: val_loss improved from 0.01493 to 0.01492, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0044 - val_loss: 0.0149
# Epoch 45/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0040
# Epoch 45: val_loss improved from 0.01492 to 0.01461, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0045 - val_loss: 0.0146
# Epoch 46/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0033
# Epoch 46: val_loss did not improve from 0.01461
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0040 - val_loss: 0.0148
# Epoch 47/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 47: val_loss improved from 0.01461 to 0.01431, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0042 - val_loss: 0.0143
# Epoch 48/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 48: val_loss did not improve from 0.01431
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0036 - val_loss: 0.0143
# Epoch 49/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0033
# Epoch 49: val_loss did not improve from 0.01431
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0037 - val_loss: 0.0148
# Epoch 50/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 50: val_loss improved from 0.01431 to 0.01401, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0140
# Epoch 51/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 51: val_loss did not improve from 0.01401
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0040 - val_loss: 0.0145
# Epoch 52/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0037
# Epoch 52: val_loss improved from 0.01401 to 0.01394, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0043 - val_loss: 0.0139
# Epoch 53/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0037
# Epoch 53: val_loss did not improve from 0.01394
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0040 - val_loss: 0.0142
# Epoch 54/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0036
# Epoch 54: val_loss did not improve from 0.01394
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0044 - val_loss: 0.0141
# Epoch 55/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0043
# Epoch 55: val_loss improved from 0.01394 to 0.01370, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0137
# Epoch 56/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 56: val_loss did not improve from 0.01370
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0042 - val_loss: 0.0137
# Epoch 57/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 57: val_loss improved from 0.01370 to 0.01339, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0042 - val_loss: 0.0134
# Epoch 58/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0035
# Epoch 58: val_loss did not improve from 0.01339
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 0.0138
# Epoch 59/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0034
# Epoch 59: val_loss did not improve from 0.01339
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0040 - val_loss: 0.0134
# Epoch 60/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0035
# Epoch 60: val_loss did not improve from 0.01339
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0038 - val_loss: 0.0136
# Epoch 61/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0036
# Epoch 61: val_loss did not improve from 0.01339
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0041 - val_loss: 0.0137
# Epoch 62/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0045
# Epoch 62: val_loss improved from 0.01339 to 0.01302, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0046 - val_loss: 0.0130
# Epoch 63/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0028
# Epoch 63: val_loss improved from 0.01302 to 0.01301, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0032 - val_loss: 0.0130
# Epoch 64/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0028
# Epoch 64: val_loss improved from 0.01301 to 0.01296, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0031 - val_loss: 0.0130
# Epoch 65/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0031
# Epoch 65: val_loss improved from 0.01296 to 0.01284, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0035 - val_loss: 0.0128
# Epoch 66/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0031
# Epoch 66: val_loss improved from 0.01284 to 0.01279, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0034 - val_loss: 0.0128
# Epoch 67/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0033
# Epoch 67: val_loss did not improve from 0.01279
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0035 - val_loss: 0.0133
# Epoch 68/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0031
# Epoch 68: val_loss did not improve from 0.01279
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0037 - val_loss: 0.0130
# Epoch 69/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 69: val_loss improved from 0.01279 to 0.01258, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0041 - val_loss: 0.0126
# Epoch 70/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0032
# Epoch 70: val_loss improved from 0.01258 to 0.01221, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 0.0122
# Epoch 71/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0030
# Epoch 71: val_loss did not improve from 0.01221
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0035 - val_loss: 0.0124
# Epoch 72/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0037
# Epoch 72: val_loss did not improve from 0.01221
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0041 - val_loss: 0.0123
# Epoch 73/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0035
# Epoch 73: val_loss did not improve from 0.01221
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0040 - val_loss: 0.0122
# Epoch 74/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 74: val_loss improved from 0.01221 to 0.01219, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0039 - val_loss: 0.0122
# Epoch 75/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 75: val_loss improved from 0.01219 to 0.01211, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 0.0121
# Epoch 76/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0028
# Epoch 76: val_loss improved from 0.01211 to 0.01192, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0030 - val_loss: 0.0119
# Epoch 77/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 77: val_loss did not improve from 0.01192
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0128
# Epoch 78/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0028
# Epoch 78: val_loss did not improve from 0.01192
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0030 - val_loss: 0.0123
# Epoch 79/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0035
# Epoch 79: val_loss improved from 0.01192 to 0.01166, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0035 - val_loss: 0.0117
# Epoch 80/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0030
# Epoch 80: val_loss improved from 0.01166 to 0.01146, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0035 - val_loss: 0.0115
# Epoch 81/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0030
# Epoch 81: val_loss improved from 0.01146 to 0.01130, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0033 - val_loss: 0.0113
# Epoch 82/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0031
# Epoch 82: val_loss improved from 0.01130 to 0.01120, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0035 - val_loss: 0.0112
# Epoch 83/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0029
# Epoch 83: val_loss improved from 0.01120 to 0.01103, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0032 - val_loss: 0.0110
# Epoch 84/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0028
# Epoch 84: val_loss improved from 0.01103 to 0.01099, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0110
# Epoch 85/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0027
# Epoch 85: val_loss did not improve from 0.01099
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 0.0114
# Epoch 86/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 86: val_loss did not improve from 0.01099
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 0.0111
# Epoch 87/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0034
# Epoch 87: val_loss improved from 0.01099 to 0.01089, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0038 - val_loss: 0.0109
# Epoch 88/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0035
# Epoch 88: val_loss did not improve from 0.01089
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0041 - val_loss: 0.0110
# Epoch 89/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0037
# Epoch 89: val_loss did not improve from 0.01089
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0042 - val_loss: 0.0110
# Epoch 90/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0044
# Epoch 90: val_loss improved from 0.01089 to 0.01061, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0045 - val_loss: 0.0106
# Epoch 91/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0033
# Epoch 91: val_loss improved from 0.01061 to 0.01049, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0039 - val_loss: 0.0105
# Epoch 92/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0029
# Epoch 92: val_loss improved from 0.01049 to 0.01035, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0033 - val_loss: 0.0104
# Epoch 93/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0027
# Epoch 93: val_loss improved from 0.01035 to 0.01034, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0103
# Epoch 94/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 94: val_loss improved from 0.01034 to 0.01032, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0027 - val_loss: 0.0103
# Epoch 95/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0023
# Epoch 95: val_loss improved from 0.01032 to 0.00998, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0100
# Epoch 96/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0022
# Epoch 96: val_loss did not improve from 0.00998
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0025 - val_loss: 0.0102
# Epoch 97/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 97: val_loss improved from 0.00998 to 0.00994, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0031 - val_loss: 0.0099
# Epoch 98/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0030
# Epoch 98: val_loss improved from 0.00994 to 0.00974, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0032 - val_loss: 0.0097
# Epoch 99/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0025
# Epoch 99: val_loss improved from 0.00974 to 0.00964, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0096
# Epoch 100/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0028
# Epoch 100: val_loss improved from 0.00964 to 0.00949, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0030 - val_loss: 0.0095
# Epoch 101/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0024
# Epoch 101: val_loss improved from 0.00949 to 0.00940, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0027 - val_loss: 0.0094
# Epoch 102/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0025
# Epoch 102: val_loss improved from 0.00940 to 0.00934, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0027 - val_loss: 0.0093
# Epoch 103/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0025
# Epoch 103: val_loss did not improve from 0.00934
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0094
# Epoch 104/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 104: val_loss improved from 0.00934 to 0.00918, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0033 - val_loss: 0.0092
# Epoch 105/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 105: val_loss improved from 0.00918 to 0.00903, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0034 - val_loss: 0.0090
# Epoch 106/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0032
# Epoch 106: val_loss did not improve from 0.00903
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0034 - val_loss: 0.0091
# Epoch 107/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 107: val_loss improved from 0.00903 to 0.00894, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0036 - val_loss: 0.0089
# Epoch 108/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 108: val_loss did not improve from 0.00894
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0090
# Epoch 109/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0028
# Epoch 109: val_loss improved from 0.00894 to 0.00871, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0030 - val_loss: 0.0087
# Epoch 110/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0024
# Epoch 110: val_loss improved from 0.00871 to 0.00870, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0027 - val_loss: 0.0087
# Epoch 111/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0025
# Epoch 111: val_loss did not improve from 0.00870
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0026 - val_loss: 0.0088
# Epoch 112/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0023
# Epoch 112: val_loss improved from 0.00870 to 0.00869, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0087
# Epoch 113/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 113: val_loss improved from 0.00869 to 0.00849, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0027 - val_loss: 0.0085
# Epoch 114/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 114: val_loss improved from 0.00849 to 0.00837, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0025 - val_loss: 0.0084
# Epoch 115/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0023
# Epoch 115: val_loss did not improve from 0.00837
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0024 - val_loss: 0.0088
# Epoch 116/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0031
# Epoch 116: val_loss improved from 0.00837 to 0.00825, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0034 - val_loss: 0.0083
# Epoch 117/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0021
# Epoch 117: val_loss improved from 0.00825 to 0.00819, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0024 - val_loss: 0.0082
# Epoch 118/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 118: val_loss improved from 0.00819 to 0.00810, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0081
# Epoch 119/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 119: val_loss improved from 0.00810 to 0.00784, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0025 - val_loss: 0.0078
# Epoch 120/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0023
# Epoch 120: val_loss did not improve from 0.00784
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0025 - val_loss: 0.0079
# Epoch 121/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0024
# Epoch 121: val_loss did not improve from 0.00784
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0078
# Epoch 122/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 122: val_loss did not improve from 0.00784
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0033 - val_loss: 0.0080
# Epoch 123/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0028
# Epoch 123: val_loss did not improve from 0.00784
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0033 - val_loss: 0.0079
# Epoch 124/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0025
# Epoch 124: val_loss did not improve from 0.00784
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0082
# Epoch 125/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0031
# Epoch 125: val_loss did not improve from 0.00784
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0036 - val_loss: 0.0079
# Epoch 126/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0031
# Epoch 126: val_loss did not improve from 0.00784
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0034 - val_loss: 0.0080
# Epoch 127/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0029
# Epoch 127: val_loss improved from 0.00784 to 0.00767, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0033 - val_loss: 0.0077
# Epoch 128/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0022
# Epoch 128: val_loss improved from 0.00767 to 0.00753, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0024 - val_loss: 0.0075
# Epoch 129/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 129: val_loss improved from 0.00753 to 0.00748, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0020 - val_loss: 0.0075
# Epoch 130/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0020
# Epoch 130: val_loss improved from 0.00748 to 0.00741, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0022 - val_loss: 0.0074
# Epoch 131/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 131: val_loss improved from 0.00741 to 0.00737, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0023 - val_loss: 0.0074
# Epoch 132/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0020
# Epoch 132: val_loss improved from 0.00737 to 0.00722, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0023 - val_loss: 0.0072
# Epoch 133/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0019
# Epoch 133: val_loss did not improve from 0.00722
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0022 - val_loss: 0.0073
# Epoch 134/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0020
# Epoch 134: val_loss improved from 0.00722 to 0.00722, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0024 - val_loss: 0.0072
# Epoch 135/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0021
# Epoch 135: val_loss improved from 0.00722 to 0.00722, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0025 - val_loss: 0.0072
# Epoch 136/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 136: val_loss improved from 0.00722 to 0.00709, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0020 - val_loss: 0.0071
# Epoch 137/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 137: val_loss improved from 0.00709 to 0.00686, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0024 - val_loss: 0.0069
# Epoch 138/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0021
# Epoch 138: val_loss did not improve from 0.00686
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0071
# Epoch 139/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 139: val_loss did not improve from 0.00686
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0069
# Epoch 140/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0022
# Epoch 140: val_loss did not improve from 0.00686
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0023 - val_loss: 0.0071
# Epoch 141/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 141: val_loss did not improve from 0.00686
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0026 - val_loss: 0.0069
# Epoch 142/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0018
# Epoch 142: val_loss did not improve from 0.00686
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0019 - val_loss: 0.0071
# Epoch 143/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 143: val_loss improved from 0.00686 to 0.00679, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0021 - val_loss: 0.0068
# Epoch 144/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 144: val_loss did not improve from 0.00679
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0022 - val_loss: 0.0070
# Epoch 145/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 145: val_loss did not improve from 0.00679
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0069
# Epoch 146/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0021
# Epoch 146: val_loss did not improve from 0.00679
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0024 - val_loss: 0.0069
# Epoch 147/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0021
# Epoch 147: val_loss improved from 0.00679 to 0.00672, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0067
# Epoch 148/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0023
# Epoch 148: val_loss did not improve from 0.00672
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0028 - val_loss: 0.0070
# Epoch 149/300
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0019
# Epoch 149: val_loss did not improve from 0.00672
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0070
# Epoch 150/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0028
# Epoch 150: val_loss did not improve from 0.00672
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0030 - val_loss: 0.0074
# Epoch 151/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 151: val_loss did not improve from 0.00672
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0072
# Epoch 152/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 152: val_loss did not improve from 0.00672
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0068
# Epoch 153/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0022
# Epoch 153: val_loss improved from 0.00672 to 0.00660, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0024 - val_loss: 0.0066
# Epoch 154/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0016
# Epoch 154: val_loss did not improve from 0.00660
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0068
# Epoch 155/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0017
# Epoch 155: val_loss did not improve from 0.00660
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0067
# Epoch 156/300
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0018
# Epoch 156: val_loss did not improve from 0.00660
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0066
# Epoch 157/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0018
# Epoch 157: val_loss did not improve from 0.00660
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0067
# Epoch 158/300
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0019
# Epoch 158: val_loss did not improve from 0.00660
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0067
# Epoch 159/300
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0017
# Epoch 159: val_loss did not improve from 0.00660
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0018 - val_loss: 0.0069
# Epoch 160/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 160: val_loss did not improve from 0.00660
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0021 - val_loss: 0.0067
# Epoch 161/300
# 52/53 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 161: val_loss did not improve from 0.00660
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0024 - val_loss: 0.0068
# Epoch 162/300
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0027
# Epoch 162: val_loss did not improve from 0.00660
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0028 - val_loss: 0.0067
# Epoch 163/300
# 53/53 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 163: val_loss did not improve from 0.00660
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0027 - val_loss: 0.0067

# %%
plt.figure(figsize=(16,7))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model

model_from_saved_checkpoint = load_model(checkpoint_path) #loading best model

# %%
# Transformation to original form and making the predictions on test
pred_ETH_test = model_from_saved_checkpoint.predict(X_test)
pred_ETH_test = scaler_test.inverse_transform(pred_ETH_test.reshape(-1, 1))
test_actual = scaler_test.inverse_transform(y_test.reshape(-1, 1))

# %%
plt.figure(figsize=(16,7))
plt.plot(pred_ETH_test, 'r', marker='.', label='Predicted Test')
plt.plot(test_actual, marker='.', label='Actual Test')
plt.legend()
plt.show()

# %%
# Transformation to original form and making the predictions on train
pred_ETH_train = model_from_saved_checkpoint.predict(X_train)
pred_ETH_train = scaler_train.inverse_transform(pred_ETH_train.reshape(-1, 1))
train_actual = scaler_train.inverse_transform(y_train.reshape(-1, 1))

# %%
plt.figure(figsize=(16,7))
plt.plot(pred_ETH_train, 'r', marker='.', label='Predicted Train')
plt.plot(train_actual, marker='.', label='Actual Train')
plt.legend()
plt.show()

# %% [markdown]
# # PRICE PREDICTION ON FUTURE 5 DAYS

# %%
#putting into the model the past 'back_period' values and getting future values as output.
back_period = 5 

X_test_last_5_days = X_test[X_test.shape[0] - back_period :  ]

X_test_last_5_days.shape
# Out:
# (5, 5, 1)

# %%
X_test_last_5_days
# Out:
# array([[[0.7817722 ],
#         [0.70491117],
#         [0.86259389],
#         [0.89385255],
#         [0.9744577 ]],
#
#        [[0.70491117],
#         [0.86259389],
#         [0.89385255],
#         [0.9744577 ],
#         [1.        ]],
#
#        [[0.86259389],
#         [0.89385255],
#         [0.9744577 ],
#         [1.        ],
#         [0.9527808 ]],
#
#        [[0.89385255],
#         [0.9744577 ],
#         [1.        ],
#         [0.9527808 ],
#         [0.91824332]],
#
#        [[0.9744577 ],
#         [1.        ],
#         [0.9527808 ],
#         [0.91824332],
#         [0.89058188]]])

# %%
predicted_5_days_price_test = []

for i in range(5):  
  predicted_price_test = model_from_saved_checkpoint.predict(X_test_last_5_days[i:i+1]) 
  predicted_price_test = scaler_test.inverse_transform(predicted_price_test.reshape(-1, 1))
  predicted_5_days_price_test.append(predicted_price_test)
print("prediction ", np.array(predicted_5_days_price_test)) #predicting 5 future days
# Out:
# prediction  [[[1885.5251]]
#
#  [[1918.6761]]
#
#  [[1936.1642]]
#
#  [[1911.0549]]
#
#  [[1897.4269]]]

# %%
predicted_5_days_price_test = np.array(predicted_5_days_price_test)

predicted_5_days_price_test.shape
# Out:
# (5, 1, 1)

# %%
predicted_5_days_price_test
# Out:
# array([[[1885.5251]],
#
#        [[1918.6761]],
#
#        [[1936.1642]],
#
#        [[1911.0549]],
#
#        [[1897.4269]]], dtype=float32)

# %%
predicted_5_days_price_test = predicted_5_days_price_test.flatten()

predicted_5_days_price_test
# Out:
# array([1885.5251, 1918.6761, 1936.1642, 1911.0549, 1897.4269],
#       dtype=float32)

# %%
pred_ETH_test = pred_ETH_test.flatten()

pred_ETH_test
# Out:
# array([1126.7018, 1179.1515, 1228.967 , 1229.5544, 1220.3044, 1187.4744,
#        1150.5248, 1119.9471, 1101.0663, 1094.8114, 1095.3512, 1120.7382,
#        1137.0458, 1168.2919, 1216.8866, 1234.6968, 1237.7616, 1209.9904,
#        1162.0107, 1115.9419, 1111.0083, 1147.7313, 1202.4656, 1323.959 ,
#        1364.7175, 1597.3252, 1573.05  , 1561.8442, 1600.4342, 1570.7931,
#        1578.7043, 1618.0072, 1513.334 , 1483.58  , 1635.1061, 1711.1482,
#        1732.4702, 1714.8723, 1702.9017, 1668.7501, 1657.7749, 1645.0668,
#        1634.7714, 1722.0858, 1707.2488, 1714.559 , 1760.3508, 1732.6599,
#        1803.0227, 1842.8357, 1885.5251, 1918.6761, 1936.1642, 1911.0549,
#        1897.4269], dtype=float32)

# %%
pred_ETH_test_concatenated = np.concatenate((pred_ETH_test, predicted_5_days_price_test))

pred_ETH_test_concatenated

pred_ETH_test_concatenated.shape
# Out:
# (60,)

# %%
# Predictions of Test Data (including the Future 5-days )
plt.figure(figsize=(16,7))

plt.plot(pred_ETH_test_concatenated, 'r', marker='.', label='Predicted Test')

plt.plot(test_actual, marker='.', label='Actual Test')

plt.legend()

plt.show()
